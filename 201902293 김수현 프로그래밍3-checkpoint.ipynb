# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/ksh76/Downloads/korea/Enter_korea_by_purpose.csv', engine='python')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 이 데이터는 한국관광공사(KOT)의 출처로 외국인이 한국에 방문하는 목적에 대한 데이터이다.
# 데이터 자료는 날짜,국가,방문자수,전년 대비 방문자수 증가율, 당월 전체 방문자 비율,
# 관광, 사업, 공무, 공부, 기타 순으로 나열되어있다.

# %% [markdown]
# 가설
# 1.코로나 바이러스가 발생한 시기인 2020년 1월 한국을 방문하는 방문객수는 줄어들었을 것이다.
# 2.한국을 방문하는 목적중 관광이 가장 많은 비중을 차지할 것이다.

# %%
df
# Out:
#        date           nation  visitor     growth      share  tourism  \
# 0    2019-1            China   392814  28.737870  35.555117   320113
# 1    2019-1            Japan   206526  23.606830  18.693468   198805
# 2    2019-1           Taiwan    87954  16.003693   7.961057    86393
# 3    2019-1        Hong Kong    35896   3.533212   3.249086    34653
# 4    2019-1            Macao     2570 -12.376406   0.232621     2506
# ..      ...              ...      ...        ...        ...      ...
# 955  2020-4   Oceania others       13 -97.239915   0.044195        0
# 956  2020-4     South Africa       22 -98.101812   0.074792        2
# 957  2020-4    Africa others      177 -95.412131   0.601734       11
# 958  2020-4        Stateless        3 -95.312500   0.010199        0
# 959  2020-4  Overseas Korean      698 -96.540101   2.372939        0
#
#      business  official affairs  studying  others
# 0        2993               138      8793   60777
# ...

# %% [markdown]
# shape를 사용하여 960개의 행과 10개의 열이 있는 속성을 알아내었다.

# %%
df.shape
# Out:
# (960, 10)

# %% [markdown]
# info 함수를 사용하여 데이터에 대한 요약정보를 알아본다.
# 이 데이터는 pandas의 데이터프레임 클래스이다.
# 0부터 959까지 총 960로우로 구성되어있다.
# 이 데이터는 총 10개의 컬럼을 가지고 있다.
# 10개의 컬럼들은 모두 빈 곳없이 960개의 로우로 구성되어있으며 날짜와 국가는 문자형 growth와 share은 부동소수점수형
# 나머지는 정수형식으로 문자형 2개 부동소수점수형 2개 정수형 6개로 구성된 75.1+ KB메모리를 가진 데이터이다.
# .

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              960 non-null    object
#  1   nation            960 non-null    object
#  2   visitor           960 non-null    int64
#  3   growth            960 non-null    float64
#  4   share             960 non-null    float64
#  5   tourism           960 non-null    int64
#  6   business          960 non-null    int64
#  7   official affairs  960 non-null    int64
#  8   studying          960 non-null    int64
#  9   others            960 non-null    int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 75.1+ KB

# %% [markdown]
# describe함수를 사용하여 숫자형 변수에 대한 개수 평균값 표준편차 최솟값 1사분위 수 중앙값 3사분위 수 최대값을 알 수 있다.

# %%
df.describe()
# Out:
#              visitor      growth       share        tourism     business  \
# count     960.000000  960.000000  960.000000     960.000000   960.000000
# mean    20389.154167   -7.025329    1.666667   16670.187500   208.344792
# std     67275.220326   37.597348    4.913962   57689.519176   589.823196
# min         1.000000  -99.976798    0.002128       0.000000     0.000000
# 25%       890.750000  -14.043547    0.088277     412.750000     7.000000
# 50%      2476.000000    4.718441    0.238153    1478.500000    25.000000
# 75%      9901.750000   15.223269    0.916897    5826.500000   114.250000
# max    578112.000000  108.054475   37.846937  476460.000000  4034.000000
#
#        official affairs      studying        others
# count        960.000000    960.000000    960.000000
# mean          87.996875    478.831250   2943.793750
# std          363.951599   2737.783911   8830.912547
# min            0.000000      0.000000      0.000000
# ...

# %% [markdown]
# groupby함수를 이용하여 국가를 그룹화 하여 각 나라가 16개의 데이터를 가지고 있는 것을 알아내었다
# 각 나라는 2019년 1월부터 2020년 4월까지의 16개월의 데이터를 가지고 있다.

# %%
df.groupby('nation').date.count()
# Out:
# nation
# *GCC               16
# Africa others      16
# America others     16
# Asia others        16
# Austrailia         16
# Austria            16
# Bangladesh         16
# Belgium            16
# Brazil             16
# Bulgaria           16
# Cambodia           16
# Canada             16
# China              16
# Croatia            16
# Denmark            16
# Europe others      16
# Finland            16
# France             16
# Germany            16
# Greece             16
# Hong Kong          16
# India              16
# Indonesia          16
# Iran               16
# Ireland            16
# Israel             16
# Italy              16
# Japan              16
# Kazakhstan         16
# Macao              16
# Malaysia           16
# Mexico             16
# Mongolia           16
# Myanmar            16
# Netherland         16
# New Zealand        16
# Norway             16
# Oceania others     16
# Overseas Korean    16
# Pakistan           16
# Phillipines        16
# ...

# %% [markdown]
# 각 나라의 평균 방문객 수를 내림차순으로 정렬하였다.

# %%
df.groupby('nation').mean()['visitor'].sort_values(ascending=False)
# Out:
# nation
# China              414332.3750
# Japan              230973.8125
# Taiwan              89039.3125
# USA                 73169.9375
# Hong Kong           48947.4375
# Thailand            40282.6875
# Vietnam             39057.5625
# Phillipines         35035.6250
# Malaysia            28482.6250
# Russia              25039.2500
# Indonesia           19965.1250
# Singapore           16441.0000
# Canada              14443.1250
# Overseas Korean     13201.0000
# Austrailia          12187.3750
# India               10015.7500
# UK                   9989.3750
# Germany              8448.3750
# Mongolia             8350.6875
# France               7712.0625
# Uzbekistan           6380.5000
# Myanmar              5436.0625
# Asia others          5305.7500
# Kazakhstan           3817.3125
# Macao                3645.5625
# Africa others        3395.0000
# Italy                3390.3125
# Europe others        3254.3125
# Cambodia             3143.0625
# America others       2974.8125
# ...

# %% [markdown]
# 평균 방문객 수를 내림차순으로 정렬하여 상위 5개의 나라를 선정하였다.
# 방문객 수는 중국 일본 타이완 미국 홍콩 순으로 많았다.

# %%
df.groupby('nation').mean()['visitor'].sort_values(ascending=False).head()
# Out:
# nation
# China        414332.3750
# Japan        230973.8125
# Taiwan        89039.3125
# USA           73169.9375
# Hong Kong     48947.4375
# Name: visitor, dtype: float64

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of        date           nation  visitor     growth      share  tourism  \
# 0    2019-1            China   392814  28.737870  35.555117   320113
# 1    2019-1            Japan   206526  23.606830  18.693468   198805
# 2    2019-1           Taiwan    87954  16.003693   7.961057    86393
# 3    2019-1        Hong Kong    35896   3.533212   3.249086    34653
# 4    2019-1            Macao     2570 -12.376406   0.232621     2506
# ..      ...              ...      ...        ...        ...      ...
# 955  2020-4   Oceania others       13 -97.239915   0.044195        0
# 956  2020-4     South Africa       22 -98.101812   0.074792        2
# 957  2020-4    Africa others      177 -95.412131   0.601734       11
# 958  2020-4        Stateless        3 -95.312500   0.010199        0
# 959  2020-4  Overseas Korean      698 -96.540101   2.372939        0
#
#      business  official affairs  studying  others
# ...

# %% [markdown]
# 방문객 수를 내림차순으로 나타내보았다.

# %%
df.sort_values("visitor", ascending=False)
# Out:
#         date      nation  visitor     growth      share  tourism  business  \
# 420   2019-8       China   578112  20.908521  36.444075   451570      3625
# 540  2019-10       China   567695  19.437542  34.277063   476460      3967
# 480   2019-9       China   541350  24.564249  37.087302   432018      3873
# 360   2019-7       China   519132  26.513573  35.849999   439699      3587
# 660  2019-12       China   508877  22.244216  34.929041   433577      3951
# ..       ...         ...      ...        ...        ...      ...       ...
# 898   2020-3   Stateless       11 -80.701754   0.013174        7         0
# 920   2020-4  Bangladesh       11 -99.165402   0.037396        2         0
# 913   2020-4  Uzbekistan        7 -99.905123   0.023797        1         0
# 958   2020-4   Stateless        3 -95.312500   0.010199        0         0
# 904   2020-4       Macao        1 -99.976798   0.003400        1         0
#
#      official affairs  studying  others
# ...

# %% [markdown]
# 그 중 상위 10개를 나열하였더니 모두 중국으로 중국의 방문객이 압도적으로 많은 비중을 차지하는 것을 알 수 있다.

# %%
df.sort_values("visitor", ascending=False).head(10)
# Out:
#         date nation  visitor     growth      share  tourism  business  \
# 420   2019-8  China   578112  20.908521  36.444075   451570      3625
# 540  2019-10  China   567695  19.437542  34.277063   476460      3967
# 480   2019-9  China   541350  24.564249  37.087302   432018      3873
# 360   2019-7  China   519132  26.513573  35.849999   439699      3587
# 660  2019-12  China   508877  22.244216  34.929041   433577      3951
# 600  2019-11  China   505369  25.012121  34.699185   426849      4020
# 240   2019-5  China   500413  35.165657  33.682331   413949      4034
# 180   2019-4  China   493250  34.545722  30.166978   410542      3575
# 120   2019-3  China   487623  20.874389  31.753711   369165      3933
# 720   2020-1  China   481681  22.623175  37.846937   393336      2813
#
#      official affairs  studying  others
# 420               388     44291   78238
# 540               547     12722   73999
# 480               447     25545   79467
# ...

# %% [markdown]
# 모든 나라의 방문객 수를 그래프를 통하여 나타내었다.

# %%
def all_graph(df, x, y, length):
    fig,axes = plt.subplots(1,1,figsize=(10, 8))
    axes.set_title(y)
    axes.set_ylabel(y)
    axes.set_xlabel(x)
    axes.set_xticklabels(df[x].unique(), rotation=45)
    sns.lineplot(x, y, ci=None, hue='nation', 
                 marker='o', data=df, linewidth=2)
    axes.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
all_graph(df, 'date', 'visitor', 60)
# Out:
# <ipython-input-125-7575377fbe1e>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(df[x].unique(), rotation=45)
# C:\Users\ksh76\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 중국, 일본, 대만, 미국이 한국을 방문한 대부분의 방문객을 차지한다는 것을 보여주었다.
# 하지만 너무 많은 나라의 그래프로 인해 잘 파악하기 힘드므로 가장 비중이 높은 중국 일본 대만 미국의 그래프를 따로 나타내었다.

# %%
def time_visitor_graph(name):
    fig,axes = plt.subplots(1,1,figsize=(10, 8))
    x = df[df['nation']==name].date
    y = df[df['nation']==name].visitor
    axes.set_title(name)
    axes.set_ylabel("The number of visitors")
    axes.set_xlabel("Date")
    axes.set_xticklabels(x, rotation=45)
    axes.plot(x, y, linewidth=3.0)

# %% [markdown]
# 가장 많은 비중을 차지하는 중국의 방문객수의 그래프이다.
# 그래프를 보면 2020년 1월 급격히 방문객 수가 줄어드는 모습을 볼 수 있다.

# %%
time_visitor_graph('China')
# Out:
# <ipython-input-108-f14cc2530602>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(x, rotation=45)

# %% [markdown]
# 두번째로 많은 방문객 수를 차지하는 일본의 그래프이다.
# 일본은 2020년 2월 방문객 수가 급격히 줄어드는 모습을 볼 수 있다.

# %%
time_visitor_graph('Japan')
# Out:
# <ipython-input-108-f14cc2530602>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(x, rotation=45)

# %% [markdown]
# 다음으로 대만은 중국과 마찬가지로 2020년 2월 한국을 방문하는 사람의 수가 급격히 줄어드는 그래프로 나타난다.

# %%
time_visitor_graph('Taiwan')
# Out:
# <ipython-input-108-f14cc2530602>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(x, rotation=45)

# %% [markdown]
# 마지막으로 미국의 그래프를 살펴보았다.
# 미국은 2019년 10월 부터 방문객 수가 하락하는 모습을 보였지만 2020년1월부터 급격하게 줄어드는 경향이 있다.

# %%
time_visitor_graph('USA')
# Out:
# <ipython-input-108-f14cc2530602>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(x, rotation=45)

# %% [markdown]
# 정확한 수치를 알아보기 위해 날짜별로 방문객수 증가율을 오름차순으로 나타내보았다.
# 가장 많이 줄어든 날은 2020년 4월 3월 2월 순으로 2019년 4월과 2020년 4월을 비교하였을 때 약 8배 정도 차이나는 결과를 알 수 있다.

# %%
df.groupby('date').mean()['growth'].sort_values(ascending=True)
# Out:
# date
# 2020-4    -96.682028
# 2020-3    -86.021127
# 2020-2    -24.867550
# 2019-2     -5.504321
# 2019-3      0.129832
# 2019-1      2.032081
# 2019-5      4.969710
# 2019-7      5.736133
# 2019-10     6.876105
# 2019-11     8.295958
# 2019-6      8.410194
# 2020-1      8.555012
# 2019-12    10.380355
# 2019-4     14.086335
# 2019-8     15.572962
# 2019-9     15.625084
# Name: growth, dtype: float64

# %% [markdown]
# 또한 방문객 수를 오름차순으로 정렬하였을때 도 마찬가지로 2020년 4월 3월 2월 순으로 방문객 수가 적은 것을 알 수 있다는 통계이다.

# %%
df.groupby('date').mean()['visitor'].sort_values(ascending=True)
# Out:
# date
# 2020-4       490.250000
# 2020-3      1391.616667
# 2020-2     11420.200000
# 2019-1     18413.383333
# 2019-2     20030.033333
# 2020-1     21211.800000
# 2019-7     24134.450000
# 2019-11    24273.816667
# 2019-12    24281.466667
# 2019-9     24327.733333
# 2019-6     24603.633333
# 2019-5     24761.400000
# 2019-3     25594.016667
# 2019-8     26438.316667
# 2019-4     27251.100000
# 2019-10    27603.250000
# Name: visitor, dtype: float64

# %% [markdown]
# 2019년 1-4월 데이터를 2020년 1-4월 데이터와 직접 비교해보았다.

# %%
def month_compare_graph(name):
    fig,axes = plt.subplots(1,1,figsize=(8, 5))
    x = [1, 2, 3, 4]
    y = df[(df['date'].str.endswith(('-1', '-2', '-3', '-4'))) & (df['nation'] == name)].visitor
    
    axes.set_title(name)
    axes.set_ylabel("The number of visitors")
    axes.set_xlabel("Month")
    axes.plot(x, y[:4], c='b', linewidth=5.0, label='2019')
    axes.plot(x, y[4:], c='r', linewidth=5.0, label='2020')
    axes.legend(loc=3)

# %% [markdown]
# 가장 먼저 중국을 비교해 보았을 때 1월 중순을 기준으로 2019년도에는 상승하는 추세였지만 2020년에는 하락하는 그래프로 나타내어진다.

# %%
    month_compare_graph('China')

# %% [markdown]
# 두번째로 일본은 2월달까지는 2019년과 2020년 모두 동일하게 이어가다 2월달을 기준으로 2019년은 상승하고 2020년은 하락하는 모습을 띄고있다.

# %%
    month_compare_graph('Japan')

# %% [markdown]
# 세번째로 대만의 그래프를 살펴보았다.
# 대만도 마찬가지고 1월 중반부터 2019년과 달리 2020년에는 급격히 하락하는 모습을 볼 수 있다.

# %%
    month_compare_graph('Taiwan')

# %% [markdown]
# 마지막으로 미국의 그래프이다.
# 미국도 2019년과 비교해서 1월 초반을 기준으로 2020년의 그래프가 하락하는 모습을 볼 수 있다

# %%
 month_compare_graph('USA')

# %% [markdown]
# 한국의 방문 목적을 구분하여 수치화 하였다.
# 관광, 사업, 공무, 공부, 기타 순으로 나열하였다.

# %%
df1[['tourism','business','official affairs','studying','others']].std()
# Out:
# tourism             57689.519176
# business              589.823196
# official affairs      363.951599
# studying             2737.783911
# others               8830.912547
# dtype: float64

# %% [markdown]
# 각 목적별로 평균값을 나타내보았다.

# %%
average=[df["tourism"].mean(),
 df["business"].mean(),
 df["official affairs"].mean(),
 df["studying"].mean(),
 df["others"].mean()]

# %%
average
# Out:
# [16670.1875, 208.34479166666668, 87.996875, 478.83125, 2943.79375]

# %% [markdown]
# 각 목적의 평균값을 히스토그램 그래프로 만들어 한눈에 보기 쉽도록 하였다.
# 한국을 방문하는 목적중 가장 많은 비중을 차지하는 것은 관광이며 다음으로 기타, 공부, 사업, 공무 순으로 한국을 방문하는 것을 알 수 있다.

# %%
dfavg= pd.DataFrame({'average': average},index=['tourism', 'business', 'official affairs', 'studying','other'])
dfavg.plot.bar(y='average')
# Out:
# <AxesSubplot:>

# %%
df.groupby('date').mean()['tourism'].sort_values(ascending=True)
# Out:
# date
# 2020-4        85.583333
# 2020-3       524.950000
# 2020-2      8399.600000
# 2019-1     14738.216667
# 2019-2     15132.133333
# 2020-1     17174.950000
# 2019-9     19640.350000
# 2019-7     20312.783333
# 2019-5     20559.366667
# 2019-11    20575.050000
# 2019-6     20630.666667
# 2019-12    20788.950000
# 2019-3     20862.400000
# 2019-8     20862.733333
# 2019-4     23042.333333
# 2019-10    23392.933333
# Name: tourism, dtype: float64

# %%
df.groupby('date').mean()['studying'].sort_values(ascending=True)
# Out:
# date
# 2020-4      119.166667
# 2019-4      225.383333
# 2020-3      236.816667
# 2019-1      266.583333
# 2019-10     290.233333
# 2019-7      319.483333
# 2020-1      343.216667
# 2019-5      345.033333
# 2019-11     359.466667
# 2019-12     375.600000
# 2019-6      396.966667
# 2019-9      654.116667
# 2020-2      701.083333
# 2019-3      763.350000
# 2019-2     1079.333333
# 2019-8     1185.466667
# Name: studying, dtype: float64

# %%
def time_visitor_graph(name):
    fig,axes = plt.subplots(1,1,figsize=(10, 8))
    x = df[df.groupby('nation')'].date
    y = df[df['nation']==name].visitor
    axes.set_title(name)
    axes.set_ylabel("The number of visitors")
    axes.set_xlabel("Date")
    axes.set_xticklabels(x, rotation=45)
    axes.plot(x, y, linewidth=3.0)

# %% [markdown]
# 첫번째 가설인 '코로나가 발생하기 시작한 2020년 1월 한국을 방문하는 각 나라의 방문객 수가 줄어들 것이다'는 성립한다.
# 하지만 중국에서 첫 코로나가 발생하기 시작한 2020년 1월 보다는 세계적으로 퍼지기 시작한 2020년 2월에 방문객 수가 급격히 줄어들기 시작한 것을 알 수 있었다. 두번째 가설인 '한국을 방문하는 목적 중 가장 많은 비중을 차지하는 것은 관광일 것이다'도 성립한다.
# 한국을 방문하는 목적 데이터를 통하여 각 목적의 평균치를 계산하여 본 결과 관광이 57689.519176으로 가장 적은 비중을 차지하는 공무의 약 158배의 차이로 가장 많은 비중을 차지하였다.

# %% [markdown]
# 프로젝트를 진행하면서 느낀점과 아쉬웠던 점 첫 코로나 바이러스가 중국에서 발생하였을 때 중국에서 많은 감염자들이 한국으로 치료를 받기 위해 한국을 온다는 말을 들었던 적이 있었다. 하지만 정확한 데이터를 통하여 분석해본 결과 중국에서의 한국 방문객은 코로나바이러스가 유행한 후 급격하게 줄어들었으며 중국 이 외에 모든 나라들의 방문객 수가 줄어든 것을 데이터로 직접 확인하여 한국의 관광명소의 고요함을 더욱 실감하게 되었다.
